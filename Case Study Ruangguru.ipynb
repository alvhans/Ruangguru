# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.animation as animation
# %matplotlib notebook

# %% [markdown]
# # CASE STUDY RUANGGURU

# %%
data = pd.read_csv('Educontent Data Associate - Case Study.csv')
data.columns
# Out:
# Index(['Question ID', 'Question Created At', 'Subject', 'Class', 'Email',
#        'PackageType', 'Created vs answered hour diff'],
#       dtype='object')

# %%
data['Question Created At'] = pd.to_datetime(data['Question Created At'])
data = data.sort_values(by='Question Created At', axis=0)
data.insert(loc=2,
            column='Hour',
            value=data['Question Created At'].dt.hour)
data.insert(loc=3,
            column='Day',
            value=data['Question Created At'].dt.day_name())
data
# Out:
#        Question ID Question Created At  Hour     Day           Subject  \
# 366   AAAAAXZHMB1E 2021-07-19 02:29:03     2  Monday        Matematika
# 2286  AAAAA0P6CMA5 2021-07-19 07:09:36     7  Monday             Kimia
# 1407  AAAAAYELT3N4 2021-07-19 07:17:46     7  Monday        Matematika
# 2411  AAAAAEGAVJ27 2021-07-19 07:24:48     7  Monday             Kimia
# 607   AAAAACG47V7N 2021-07-19 07:25:51     7  Monday        Matematika
# ...            ...                 ...   ...     ...               ...
# 820   AAAAAINR6TYD 2021-08-02 08:58:32     8  Monday    Bahasa Inggris
# 1179  AAAAAG2N7D3I 2021-08-02 08:58:54     8  Monday    Bahasa Inggris
# 2477  AAAAA39LYOLI 2021-08-02 09:02:13     9  Monday  Bahasa Indonesia
# 1192  AAAAALZ97FR5 2021-08-02 09:02:53     9  Monday       IPA Terpadu
# 1676  AAAAAVZQX0YW 2021-08-02 09:11:14     9  Monday            Fisika
#
#            Class                             Email PackageType  \
# 366        9 SMP              xxxxdisdzz@gmail.com     REGULAR
# 2286  11 SMA IPA        xxxxwulandari117@gmail.com     PREMIUM
# 1407        5 SD         xxxxitriismail9@gmail.com     PREMIUM
# 2411         IPA            xxxxsabriana@gmail.com     PREMIUM
# 607   11 SMA IPA       xxxxiafransisca00@gmail.com     PREMIUM
# ...          ...                               ...         ...
# 820   10 SMA IPA         xxxxaulidayunus@gmail.com     REGULAR
# 1179  10 SMA IPA         xxxxaulidayunus@gmail.com     REGULAR
# 2477       9 SMP  xxxxirahmawati21200704@gmail.com       ELITE
# 1192        6 SD        xxxxatamimimayla@gmail.com     REGULAR
# 1676  10 SMA IPA        xxxxdaputri93536@gmail.com     PREMIUM
#
#       Created vs answered hour diff
# 366                               3
# 2286                              1
# 1407                              6
# 2411                              0
# 607                               1
# ...                             ...
# 820                               6
# 1179                              6
# 2477                              0
# 1192                              1
# 1676                             28
#
# [3285 rows x 9 columns]

# %%
print(f'''
Class --> {data['Class'].unique()}
\nSubject --> {data['Subject'].unique()}
\nPackage --> {data['PackageType'].unique()}
\nTotal Student --> {len(data['Email'].unique())}
''')
# Out:
# Class --> ['9 SMP' '11 SMA IPA' '5 SD' 'IPA' '10 SMA IPA' 'IPS' '4 SD' '7 SMP'
#  '3 SD' '8 SMP' '11 SMA IPS' '6 SD' '10 SMA IPS' nan '12 SMA IPS'
#  '12 SMA IPA']
#
# Subject --> ['Matematika' 'Kimia' 'Bahasa Inggris' 'Biologi' 'Bahasa Indonesia'
#  'Ekonomi' 'IPS Terpadu' 'Fisika' 'Sejarah' 'IPA Terpadu' 'Geografi'
#  'Sosiologi']
#
# Package --> ['REGULAR' 'PREMIUM' 'ELITE']
#
# Total Student --> 1246

# %% [markdown]
# ## Hypothetical Insight

# %%
# TIME DEPENDENT
# Rerata pengajar lewat deadline per minggu
# Hari apa aja yg pengajarnya lewat deadline, masing2 brp persentase lewat deadlinenya
# Rerata jumlah pertanyaan per pelajar per minggu nya
# Jam sibuk & Jam yang kurang pengajar
# Tingkat kesibukan per hari per bulan per Subject (line chart) + warna merah utk yg lewat deadline

# SUBJECT DEPENDENT
# Subject yang paling banyak ditanyakan
# Subject yang paling banyak dijawab lewat deadline
# Subject VS Package

# CLASS DEPENDENT
# Class VS Package

# STUDENT DEPENDENT
# Murid yang banyak dikacangin

# TEACHER DEPENDENT
# Total respon yang lewat deadline, persentase dari keseluruhan

# FUN FACT!!!
# Murid yang aktif di tiap Subject
# Data jumlah penanya dari tiap jenjang
# Penanya terbanyak
# Package paling aktif dan yang kureng


# TAMBAHAN
# Kita masih bisa liat perbedaan antar Package, tp disini Elite & Premium dianggap sama

# %%
null_data = data[data['Class'].isnull()]

# %% [markdown]
# ## Querying Time!!

# %% [markdown]
# TEACHER DEPENDENT
#
# Index(['Question ID', 'Question Created At', 'Subject', 'Class', 'Email',
#        'PackageType', 'Created vs answered hour diff'],
#       dtype='object')

# %%
# Total respon yang lewat deadline, persentase dari keseluruhan
premium_thr = 24  # 24 hour threshold
regular_thr = 48  # 48 hour threshold

def late_response(package):
    resp = data[data['PackageType'] == package]
    if package == 'PREMIUM' or package == 'ELITE':
        late = resp[resp['Created vs answered hour diff'] >= 24]
        print(f'Failed {package} service --> {len(late)} data')
        return len(late)
    else:
        late = resp[resp['Created vs answered hour diff'] >= 48]
        print(f'Failed {package} service --> {len(late)} data')
        return len(late)
        

# ELITE
el = late_response('ELITE')
# PREMIUM
pr = late_response('PREMIUM')
# REGULAR
re = late_response('REGULAR')

# TOTAL
tot = el + pr + re
print(f'\nTotal service failure --> {tot}')
# Percentage
rate = tot / len(data) * 100
print(f'Rate of service failure --> {round(rate, 2)}%')
# Out:
# Failed ELITE service --> 6 data
# Failed PREMIUM service --> 429 data
# Failed REGULAR service --> 229 data
#
# Total service failure --> 664
# Rate of service failure --> 20.21%

# %% [markdown]
# TIME DEPENDENT
#
# Index(['Question ID', 'Question Created At', 'Subject', 'Class', 'Email',
#        'PackageType', 'Created vs answered hour diff'],
#       dtype='object')

# %%
data = data.reset_index(drop=True)
data
# Out:
#        Question ID Question Created At  Hour     Day           Subject  \
# 0     AAAAAXZHMB1E 2021-07-19 02:29:03     2  Monday        Matematika
# 1     AAAAA0P6CMA5 2021-07-19 07:09:36     7  Monday             Kimia
# 2     AAAAAYELT3N4 2021-07-19 07:17:46     7  Monday        Matematika
# 3     AAAAAEGAVJ27 2021-07-19 07:24:48     7  Monday             Kimia
# 4     AAAAACG47V7N 2021-07-19 07:25:51     7  Monday        Matematika
# ...            ...                 ...   ...     ...               ...
# 3280  AAAAAINR6TYD 2021-08-02 08:58:32     8  Monday    Bahasa Inggris
# 3281  AAAAAG2N7D3I 2021-08-02 08:58:54     8  Monday    Bahasa Inggris
# 3282  AAAAA39LYOLI 2021-08-02 09:02:13     9  Monday  Bahasa Indonesia
# 3283  AAAAALZ97FR5 2021-08-02 09:02:53     9  Monday       IPA Terpadu
# 3284  AAAAAVZQX0YW 2021-08-02 09:11:14     9  Monday            Fisika
#
#            Class                             Email PackageType  \
# 0          9 SMP              xxxxdisdzz@gmail.com     REGULAR
# 1     11 SMA IPA        xxxxwulandari117@gmail.com     PREMIUM
# 2           5 SD         xxxxitriismail9@gmail.com     PREMIUM
# 3            IPA            xxxxsabriana@gmail.com     PREMIUM
# 4     11 SMA IPA       xxxxiafransisca00@gmail.com     PREMIUM
# ...          ...                               ...         ...
# 3280  10 SMA IPA         xxxxaulidayunus@gmail.com     REGULAR
# 3281  10 SMA IPA         xxxxaulidayunus@gmail.com     REGULAR
# 3282       9 SMP  xxxxirahmawati21200704@gmail.com       ELITE
# 3283        6 SD        xxxxatamimimayla@gmail.com     REGULAR
# 3284  10 SMA IPA        xxxxdaputri93536@gmail.com     PREMIUM
#
#       Created vs answered hour diff
# 0                                 3
# 1                                 1
# 2                                 6
# 3                                 0
# 4                                 1
# ...                             ...
# 3280                              6
# 3281                              6
# 3282                              0
# 3283                              1
# 3284                             28
#
# [3285 rows x 9 columns]

# %%
# Rerata pengajar lewat deadline per minggu
week_list = []
week = 1
for i in data.index:
    week_list.append(week)
    if data.iloc[i]['Day'] == 'Sunday' and data.iloc[i+1]['Day'] == 'Monday':
        week += 1
data.insert(loc = 1,
            column = 'Week',
            value = week_list)

# %%
# Late data per week
def late_data(package, x):
    per_week = data[data['Week'] == x]
    resp = per_week[per_week['PackageType'] == package]
    if package == 'PREMIUM' or package == 'ELITE':
        late = resp[resp['Created vs answered hour diff'] >= 24]
        return len(late)
    else:
        late = resp[resp['Created vs answered hour diff'] >= 48]
        return len(late)


# Week 1
week1 = (late_data('ELITE', 1) + 
         late_data('PREMIUM', 1) + 
         late_data('REGULAR', 1)) / len(data[data['Week'] == 1])
# Week 2
week2 = (late_data('ELITE', 2) + 
         late_data('PREMIUM', 2) + 
         late_data('REGULAR', 2)) / len(data[data['Week'] == 2])
# Week 3
week3 = (late_data('ELITE', 3) + 
         late_data('PREMIUM', 3) + 
         late_data('REGULAR', 3)) / len(data[data['Week'] == 3])

# Average
avg_late_per_week = (week1 + week2 + week3) / 3 * 100
print(f'Fail rate per week --> {round(avg_late_per_week, 2)}%')
# Out:
# Fail rate per week --> 19.36%

# %%
data
# Out:
#        Question ID  Week Question Created At  Hour     Day           Subject  \
# 0     AAAAAXZHMB1E     1 2021-07-19 02:29:03     2  Monday        Matematika
# 1     AAAAA0P6CMA5     1 2021-07-19 07:09:36     7  Monday             Kimia
# 2     AAAAAYELT3N4     1 2021-07-19 07:17:46     7  Monday        Matematika
# 3     AAAAAEGAVJ27     1 2021-07-19 07:24:48     7  Monday             Kimia
# 4     AAAAACG47V7N     1 2021-07-19 07:25:51     7  Monday        Matematika
# ...            ...   ...                 ...   ...     ...               ...
# 3280  AAAAAINR6TYD     3 2021-08-02 08:58:32     8  Monday    Bahasa Inggris
# 3281  AAAAAG2N7D3I     3 2021-08-02 08:58:54     8  Monday    Bahasa Inggris
# 3282  AAAAA39LYOLI     3 2021-08-02 09:02:13     9  Monday  Bahasa Indonesia
# 3283  AAAAALZ97FR5     3 2021-08-02 09:02:53     9  Monday       IPA Terpadu
# 3284  AAAAAVZQX0YW     3 2021-08-02 09:11:14     9  Monday            Fisika
#
#            Class                             Email PackageType  \
# 0          9 SMP              xxxxdisdzz@gmail.com     REGULAR
# 1     11 SMA IPA        xxxxwulandari117@gmail.com     PREMIUM
# 2           5 SD         xxxxitriismail9@gmail.com     PREMIUM
# 3            IPA            xxxxsabriana@gmail.com     PREMIUM
# 4     11 SMA IPA       xxxxiafransisca00@gmail.com     PREMIUM
# ...          ...                               ...         ...
# 3280  10 SMA IPA         xxxxaulidayunus@gmail.com     REGULAR
# 3281  10 SMA IPA         xxxxaulidayunus@gmail.com     REGULAR
# 3282       9 SMP  xxxxirahmawati21200704@gmail.com       ELITE
# 3283        6 SD        xxxxatamimimayla@gmail.com     REGULAR
# 3284  10 SMA IPA        xxxxdaputri93536@gmail.com     PREMIUM
#
#       Created vs answered hour diff
# 0                                 3
# 1                                 1
# 2                                 6
# 3                                 0
# 4                                 1
# ...                             ...
# 3280                              6
# 3281                              6
# 3282                              0
# 3283                              1
# 3284                             28
#
# [3285 rows x 10 columns]

# %%
# Hari apa aja yg pengajarnya lewat deadline, masing2 brp persentase lewat deadlinenya
def late_df(package):
    resp = data[data['PackageType'] == package]
    if package == 'PREMIUM' or package == 'ELITE':
        late = resp[resp['Created vs answered hour diff'] >= 24]
        return late
    else:
        late = resp[resp['Created vs answered hour diff'] >= 48]
        return late

    
# ELITE
el_late_df = late_df('ELITE')
# PREMIUM
pr_late_df = late_df('PREMIUM')
# REGULAR
re_late_df = late_df('REGULAR')

# Day with late responses
late_response = el_late_df.append(pr_late_df)
late_response = late_response.append(re_late_df)
late_response = late_response.reset_index(drop=True)
late_response['Day'].unique()
# Out:
# array(['Thursday', 'Friday', 'Saturday', 'Monday', 'Tuesday', 'Wednesday',
#        'Sunday'], dtype=object)

# %%
for r in data['Day'].unique():
    print(f'{r} late response --> {len(late_response[late_response["Day"] == r])}')
    print(len(late_response[late_response["Day"] == r]) /
          len(data[data['Day'] == r]) * 100, '%')
# Out:
# Monday late response --> 27
# 4.972375690607735 %
# Tuesday late response --> 31
# 6.695464362850973 %
# Wednesday late response --> 66
# 12.571428571428573 %
# Thursday late response --> 169
# 25.375375375375377 %
# Friday late response --> 210
# 38.60294117647059 %
# Saturday late response --> 130
# 44.827586206896555 %
# Sunday late response --> 31
# 12.204724409448819 %

# %%
for r in data['Day'].unique():
    print(f'{r} response --> {len(data[data["Day"] == r])}')
# Out:
# Monday response --> 543
# Tuesday response --> 463
# Wednesday response --> 525
# Thursday response --> 666
# Friday response --> 544
# Saturday response --> 290
# Sunday response --> 254

# %%
# Rerata jumlah pertanyaan per pelajar per minggu nya
import math
weekly_qna_student = []
weekly_qna = []
for s in data['Email'].unique():
    for w in range(1, 4):
        which_week = data[data['Week'] == w]
        weekly_qna.append(len(which_week[which_week['Email'] == s]))
    weekly_qna_student.append(math.ceil(np.mean(weekly_qna)))
    weekly_qna = []
print(len(weekly_qna_student))
print(f'Weekly question per student --> {np.mean(weekly_qna_student)}')
# Out:
# 1246
# Weekly question per student --> 1.377207062600321

# %%
# Jam sibuk & Jam yang kurang pengajar
# Jam Sibuk
active_hour = data['Hour'].unique()
active_hour.sort()
for h in active_hour:
    load_per_hour = len(data[data['Hour'] == h])
    print(f'At {h} --> {load_per_hour} questions')
# Out:
# At 0 --> 12 questions
# At 1 --> 1 questions
# At 2 --> 1 questions
# At 3 --> 4 questions
# At 4 --> 7 questions
# At 5 --> 33 questions
# At 6 --> 46 questions
# At 7 --> 168 questions
# At 8 --> 284 questions
# At 9 --> 339 questions
# At 10 --> 306 questions
# At 11 --> 254 questions
# At 12 --> 246 questions
# At 13 --> 212 questions
# At 14 --> 165 questions
# At 15 --> 149 questions
# At 16 --> 122 questions
# At 17 --> 96 questions
# At 18 --> 131 questions
# At 19 --> 170 questions
# At 20 --> 201 questions
# At 21 --> 192 questions
# At 22 --> 96 questions
# At 23 --> 50 questions

# %%
# Jam yang kurang pengajar
chaos_hour = late_response['Hour'].unique()
chaos_hour.sort()
for h in chaos_hour:
    chaos_load = len(late_response[late_response['Hour'] == h])
    tot_load = len(data[data['Hour'] == h])
    print(f'At {h} --> {chaos_load} questions || {round(chaos_load / tot_load * 100, 2)}%')
# Out:
# At 0 --> 5 questions || 41.67%
# At 4 --> 2 questions || 28.57%
# At 5 --> 3 questions || 9.09%
# At 6 --> 4 questions || 8.7%
# At 7 --> 31 questions || 18.45%
# At 8 --> 57 questions || 20.07%
# At 9 --> 68 questions || 20.06%
# At 10 --> 57 questions || 18.63%
# At 11 --> 55 questions || 21.65%
# At 12 --> 54 questions || 21.95%
# At 13 --> 50 questions || 23.58%
# At 14 --> 31 questions || 18.79%
# At 15 --> 35 questions || 23.49%
# At 16 --> 24 questions || 19.67%
# At 17 --> 26 questions || 27.08%
# At 18 --> 24 questions || 18.32%
# At 19 --> 30 questions || 17.65%
# At 20 --> 45 questions || 22.39%
# At 21 --> 34 questions || 17.71%
# At 22 --> 20 questions || 20.83%
# At 23 --> 9 questions || 18.0%

# %%
# Tingkat kesibukan per hari per minggu per Subject (line chart) + warna merah utk yg lewat deadline
data.insert(loc=3,
            column='Date',
            value=data['Question Created At'].dt.date)

# %%
load_daily = []
for d in data['Date'].unique():
    daily = data[data['Date'] == d]
    load_daily.append(len(daily))
load_daily
# Out:
# [161, 67, 191, 253, 253, 123, 110, 337, 396, 334, 413, 291, 167, 144, 45]

# %%
sub_load = {}
load_list = []
for s in data['Subject'].unique():
    sub_data = data[data['Subject'] == s]
    for d in data['Date'].unique():
        sub_daily = sub_data[sub_data['Date'] == d]
        load_list.append(len(sub_daily))
    sub_load[s] = load_list
    load_list = []
sub_load
# Out:
# {'Matematika': [59,
#   34,
#   85,
#   103,
#   92,
#   43,
#   39,
#   146,
#   170,
#   135,
#   158,
#   125,
#   75,
#   45,
#   7],
#  'Kimia': [20, 11, 18, 28, 37, 23, 13, 37, 48, 59, 60, 38, 19, 19, 8],
#  'Bahasa Inggris': [20, 4, 8, 13, 11, 9, 4, 10, 23, 16, 39, 23, 4, 31, 9],
#  'Biologi': [14, 8, 33, 30, 32, 7, 21, 51, 48, 33, 38, 22, 17, 15, 4],
#  'Bahasa Indonesia': [6, 2, 9, 20, 13, 8, 3, 30, 16, 18, 15, 20, 13, 6, 3],
#  'Ekonomi': [3, 0, 1, 4, 5, 1, 2, 8, 14, 3, 5, 6, 0, 1, 2],
#  'IPS Terpadu': [3, 0, 1, 1, 4, 0, 1, 1, 1, 0, 3, 0, 1, 0, 0],
#  'Fisika': [27, 3, 26, 30, 34, 19, 21, 39, 49, 46, 65, 39, 23, 19, 8],
#  'Sejarah': [5, 0, 4, 2, 12, 9, 1, 4, 6, 12, 16, 4, 5, 5, 2],
#  'IPA Terpadu': [2, 0, 3, 3, 5, 0, 2, 3, 11, 7, 2, 4, 3, 0, 1],
#  'Geografi': [2, 5, 3, 17, 8, 3, 1, 6, 9, 4, 11, 6, 6, 2, 1],
#  'Sosiologi': [0, 0, 0, 2, 0, 1, 2, 2, 1, 1, 1, 4, 1, 1, 0]}

# %% [markdown]
# SUBJECT DEPENDENT
#
# Index(['Question ID', 'Question Created At', 'Subject', 'Class', 'Email',
#        'PackageType', 'Created vs answered hour diff'],
#       dtype='object')

# %%
# Subject yang paling banyak ditanyakan
sub_tot = {}
for s in data['Subject'].unique():
    sub_df = data[data['Subject'] == s]
    sub_tot[s] = len(sub_df)
dict(sorted(sub_tot.items(),
            key=lambda item: item[1],
            reverse=True))
# Out:
# {'Matematika': 1316,
#  'Fisika': 448,
#  'Kimia': 438,
#  'Biologi': 373,
#  'Bahasa Inggris': 224,
#  'Bahasa Indonesia': 182,
#  'Sejarah': 87,
#  'Geografi': 84,
#  'Ekonomi': 55,
#  'IPA Terpadu': 46,
#  'IPS Terpadu': 16,
#  'Sosiologi': 16}

# %%
# Subject yang paling banyak dijawab lewat deadline
sub_late = {}
for s in data['Subject'].unique():
    sublate_df = late_response[late_response['Subject'] == s]
    sub_late[s] = len(sublate_df)
dict(sorted(sub_late.items(),
            key=lambda item: item[1],
            reverse=True))
# Out:
# {'Matematika': 423,
#  'Fisika': 124,
#  'Sejarah': 27,
#  'Bahasa Inggris': 20,
#  'Kimia': 19,
#  'Bahasa Indonesia': 19,
#  'Geografi': 12,
#  'IPS Terpadu': 5,
#  'Biologi': 4,
#  'IPA Terpadu': 4,
#  'Sosiologi': 4,
#  'Ekonomi': 3}

# %%
# Subject VS Package
sp = {}
for p in data['PackageType'].unique():
    print(p)
    sub_in_pack = data[data['PackageType'] == p]
    for s in data['Subject'].unique():
        sub_p = sub_in_pack[sub_in_pack['Subject'] == s]
        sp[s] = len(sub_p)
    sp = dict(sorted(sp.items(),
                     key=lambda item: item[1],
                     reverse=True))
    print(sp)
    sp = {}
# Out:
# REGULAR
# {'Matematika': 708, 'Biologi': 254, 'Fisika': 240, 'Kimia': 228, 'Bahasa Inggris': 168, 'Bahasa Indonesia': 103, 'Sejarah': 50, 'Geografi': 41, 'Ekonomi': 32, 'IPA Terpadu': 26, 'IPS Terpadu': 7, 'Sosiologi': 7}
# PREMIUM
# {'Matematika': 589, 'Kimia': 205, 'Fisika': 204, 'Biologi': 115, 'Bahasa Indonesia': 76, 'Bahasa Inggris': 54, 'Geografi': 42, 'Sejarah': 37, 'Ekonomi': 23, 'IPA Terpadu': 20, 'IPS Terpadu': 9, 'Sosiologi': 9}
# ELITE
# {'Matematika': 19, 'Kimia': 5, 'Biologi': 4, 'Fisika': 4, 'Bahasa Indonesia': 3, 'Bahasa Inggris': 2, 'Geografi': 1, 'Ekonomi': 0, 'IPS Terpadu': 0, 'Sejarah': 0, 'IPA Terpadu': 0, 'Sosiologi': 0}

# %% [markdown]
# CLASS DEPENDENT
#
# Index(['Question ID', 'Question Created At', 'Subject', 'Class', 'Email',
#        'PackageType', 'Created vs answered hour diff'],
#       dtype='object')

# %%
# Class VS Package
for c in data['Class'].unique():
    class_list = data[data['Class'] == c]['PackageType']
    print(f'{c} --> mostly {class_list.mode()}')
# Out:
# 9 SMP --> mostly 0    REGULAR
# dtype: object
# 11 SMA IPA --> mostly 0    REGULAR
# dtype: object
# 5 SD --> mostly 0    REGULAR
# dtype: object
# IPA --> mostly 0    PREMIUM
# dtype: object
# 10 SMA IPA --> mostly 0    REGULAR
# dtype: object
# IPS --> mostly 0    REGULAR
# dtype: object
# 4 SD --> mostly 0    REGULAR
# dtype: object
# 7 SMP --> mostly 0    REGULAR
# dtype: object
# 3 SD --> mostly 0    PREMIUM
# dtype: object
# 8 SMP --> mostly 0    REGULAR
# dtype: object
# 11 SMA IPS --> mostly 0    PREMIUM
# dtype: object
# 6 SD --> mostly 0    PREMIUM
# dtype: object
# 10 SMA IPS --> mostly 0    PREMIUM
# dtype: object
# nan --> mostly Series([], dtype: object)
# 12 SMA IPS --> mostly 0    PREMIUM
# dtype: object
# 12 SMA IPA --> mostly 0    PREMIUM
# dtype: object

# %%
# 12 SMA IPA --> mostly     PREMIUM
# 12 SMA IPS --> mostly     PREMIUM
# 11 SMA IPA --> mostly     REGULAR
# 11 SMA IPS --> mostly     PREMIUM
# 10 SMA IPA --> mostly     REGULAR
# 10 SMA IPS --> mostly     PREMIUM
# 9 SMP --> mostly     REGULAR
# 8 SMP --> mostly     REGULAR
# 7 SMP --> mostly     REGULAR
# 6 SD --> mostly     PREMIUM
# 5 SD --> mostly     REGULAR
# 4 SD --> mostly     REGULAR
# 3 SD --> mostly     PREMIUM
# IPA --> mostly     PREMIUM
# IPS --> mostly     REGULAR

# %% [markdown]
# STUDENT DEPENDENT
#
# Index(['Question ID', 'Question Created At', 'Subject', 'Class', 'Email',
#        'PackageType', 'Created vs answered hour diff'],
#       dtype='object')

# %%
# Murid yang banyak dikacangin
unresp_student = {}
for s in late_response['Email'].unique():
    fail_resp = late_response[late_response['Email'] == s]
    unresp_student[s] = len(fail_resp)
unresp_student = dict(sorted(unresp_student.items(),
                             key=lambda item: item[1],
                             reverse=True))
unresp_student
# Out:
# {'xxxxnnypratiwi@civil.untan.ac.id': 9,
#  'xxxxah_nurlidistia7@gmail.com': 9,
#  'xxxxanamom@gmail.com': 6,
#  'xxxxik601@gmail.com': 6,
#  'xxxxlfahlevi810@gmail.com': 5,
#  'xxxxicadeanna123@gmail.com': 5,
#  'xxxxkla2009@gmail.com': 5,
#  'xxxxllns.oce@gmail.com': 5,
#  'xxxxabillahhu@gmail.com': 4,
#  'xxxxsetyanegari@gmail.com': 4,
#  'xxxxeltheodorusw@gmail.com': 4,
#  'xxxxihamidah494@gmail.com': 4,
#  'xxxxnella5@gmail.com': 4,
#  'xxxx.wisnu.sw@gmail.com': 4,
#  'xxxxtianolubis@gmail.com': 4,
#  'xxxxiskandar05@gmail.com': 3,
#  'xxxxnisaadilla28@gmail.com': 3,
#  'xxxxelprasetya@gmail.com': 3,
#  'xxxxanatasya08@gmail.com': 3,
#  'xxxxa5723@gmail.com': 3,
#  'xxxxlicaruangguru@gmail.com': 3,
#  'xxxxan4776@gmail.com': 3,
#  'xxxxaribuannatanael27@gmail.com': 3,
#  'xxxxsh.calya131@gmail.com': 3,
#  'xxxxikafathan16@gmail.com': 3,
#  'xxxxnorra7114@gmail.com': 3,
#  'xxxxyuashazi@gmail.com': 3,
#  'xxxxkmila66@gmail.com': 3,
#  'xxxxaaath15@gmail.com': 3,
#  'xxxxanandadiva@gmail.com': 3,
#  'xxxxagraceila11@gmail.com': 3,
#  'xxxxa.d05@gmail.com': 3,
#  'xxxxnaazzhara@gmail.com': 3,
#  'xxxxtadiskavia03@gmail.com': 3,
#  'xxxxipuk7@gmail.com': 3,
#  'xxxxsiadamayanti94@gmail.com': 3,
#  'xxxxaprihxxxx76@gmail.com': 3,
#  'xxxxah.zafira@yahoo.com': 3,
#  'xxxxitabontong99@gmail.com': 3,
#  'xxxx.dianpitaxxxx@gmail.com': 3,
#  'xxxxasilvia420@gmail.com': 2,
#  'xxxxanhamdi22@gmail.com': 2,
#  'xxxxuzshira.anindya05@gmail.com': 2,
#  'xxxxadnina36@gmail.com': 2,
#  'xxxxi.salsabila@gmail.com': 2,
#  'xxxxesi@yahoo.com': 2,
#  'xxxxliaelvaretta20@gmail.com': 2,
#  'xxxxsika2006@gmail.com': 2,
#  'xxxxlaaisyah12@gmail.com': 2,
#  'xxxxsajaro765@gmail.com': 2,
#  'xxxxtamara95@gmail.com': 2,
#  'xxxxdaputridesakmade@gmail.com': 2,
#  'xxxxiasimorangkir17@gmail.com': 2,
#  'xxxxhrashakilarg@gmail.com': 2,
#  'xxxxbielmerentek@gmail.com': 2,
#  'xxxxsabriana@gmail.com': 2,
#  'xxxxndawati2904@gmail.com': 2,
#  'xxxxna1902@gmail.com': 2,
#  'xxxxriasihvrika2004@gmail.com': 2,
#  'xxxxa.eka2004@gmail.com': 2,
#  'xxxxasyahraini13@gmail.com': 2,
#  'xxxxa06.ruangguru@gmail.com': 2,
#  'xxxxafatikat@gmail.com': 2,
#  'xxxxersarah@gmail.com': 2,
#  'xxxxlkirania1809@gmail.com': 2,
#  'xxxxinarahmawati460@gmail.com': 2,
#  'xxxxsaayulestari707@gmail.com': 2,
#  'xxxxputra096@gmail.com': 2,
#  'xxxxa.oktavyani05@gmail.com': 2,
#  'xxxxnggraeni743@gmail.com': 2,
#  'xxxxrini26@gmail.com': 2,
#  'xxxxapramestia2005@gmail.com': 2,
#  'xxxxdhaniamelya28@gmail.com': 2,
#  'xxxxdharma61@gmail.com': 2,
#  'xxxxmangtryapurnamanova@gmail.com': 2,
#  'xxxxnaura3128@gmail.com': 2,
#  'xxxxelya@gmail.com': 2,
#  'xxxxesia7@gmail.com': 2,
#  'xxxxmymanurung08@gmail.com': 2,
#  'xxxxapbg87@gmail.com': 2,
#  'xxxxonlubis23@gmail.com': 2,
#  'xxxxabilaarafani@gmail.com': 2,
#  'xxxxe.pangkerego@gmail.com': 2,
#  'xxxxisalsanur29@gmail.com': 2,
#  'xxxxinaarfa@gmail.com': 2,
#  'xxxxthawidodo65@gmail.com': 2,
#  'xxxxnleonardlcc280705@gmail.com': 2,
#  'xxxxnenardinia06@gmail.com': 2,
#  'xxxxxxxxinzikri@gmail.com': 2,
#  'xxxxiandira93@gmail.com': 2,
#  'xxxxa.jhan@gmail.com': 2,
#  'xxxxanurbaeti@gmail.com': 2,
#  'xxxxinnap@gmail.com': 2,
#  'xxxxkoala18@gmail.com': 2,
#  'xxxxahrosmanur@gmail.com': 2,
#  'xxxxevinasuciashari@gmail.com': 2,
#  'xxxxarokaflorensiska@gmail.com': 2,
#  'xxxxusnia50@gmail.com': 2,
#  'xxxxsheva02@gmail.com': 2,
#  'xxxxanfachri4@gmail.com': 2,
#  'xxxxaratussolikah08@gmail.com': 2,
#  'xxxxnurazizah14@gmail.com': 2,
#  'xxxxmvina35@gmail.com': 2,
#  'xxxxaazalia05@gmail.com': 2,
#  'xxxxsari@ui.ac.id': 2,
#  'xxxxkusumawati15@gmail.com': 2,
#  'xxxxfahsk@gmail.com': 2,
#  'xxxxratulislamiyah@gmail.com': 2,
#  'xxxxmadinar580@gmail.com': 2,
#  'xxxxharani123@gmail.com': 2,
#  'xxxxntatyureni@gmail.com': 2,
#  'xxxxira2902@gmail.com': 2,
#  'xxxxiratmayanti@gmail.com': 2,
#  'xxxxasia203508@gmail.com': 2,
#  'xxxxamalia072@gmail.com': 2,
#  'xxxxhidayah28@gmail.com': 2,
#  'xxxxnikakikan@gmail.com': 2,
#  'xxxxiwahyuningsihgultom@gmail.com': 2,
#  'xxxxdamusaffa14@gmail.com': 1,
#  'xxxxal.arifin0504@gmail.com': 1,
#  'xxxxrcantik249@gmail.com': 1,
#  'xxxxabiqulkhoirot455@gmail.com': 1,
#  'xxxxanargya@gmail.com': 1,
#  'xxxxllmillancat@gmail.com': 1,
#  'xxxxssrzkhaa@gmail.com': 1,
#  'xxxxararizki@sman1ungaran.sch.id': 1,
#  'xxxxacucu705@gmail.com': 1,
#  'xxxxrya.putudaiva@gmail.com': 1,
#  'xxxxsansiregar121@gmail.com': 1,
#  'xxxx2627@gmail.com': 1,
#  'xxxxkamila733@gmail.com': 1,
#  'xxxxafatma77@gmail.com': 1,
#  'xxxxangka@gmail.com': 1,
#  'xxxxullahalfatih77@gmail.com': 1,
#  'xxxxprimadewi@gmail.com': 1,
#  'xxxxiatyas22.tyas@gmail.com': 1,
#  'xxxxenasikupml@gmail.com': 1,
#  'xxxxadwirahayu15@gmail.com': 1,
#  'xxxxidprofile@gmail.com': 1,
#  'xxxxe.saroinsong050718@gmail.com': 1,
#  'xxxxk.erna@gmail.com': 1,
#  'xxxxaaqila07@gmail.com': 1,
#  'xxxxchristians04@gmail.com': 1,
#  'xxxxhaasniputri2014@gmail.com': 1,
#  'xxxxrhabiburrahman.ah@gmail.com': 1,
#  'xxxxoliabid@gmail.com': 1,
#  'xxxxiaputrisantoso@gmail.com': 1,
#  'xxxxeliasitorus@gmail.com': 1,
#  'xxxxa2102@gmail.com': 1,
#  'xxxxidiyag10@gmail.com': 1,
#  'xxxxanrusdianto04@gmail.com': 1,
#  'xxxx.gselda24@gmail.com': 1,
#  'xxxxamyudiantoro@gmail.com': 1,
#  'xxxx9576@gmail.com': 1,
#  'xxxxtmaputrafausta@gmail.com': 1,
#  'xxxxejosheva660@gmail.com': 1,
#  'xxxxstu@gmail.com': 1,
#  'xxxxherinaitaar@gmail.com': 1,
#  'xxxxiyanti.fy1@gmail.com': 1,
#  'xxxxaoneprd@gmail.com': 1,
#  'xxxxha.patricia.7a@gmail.com': 1,
#  'xxxxawati3809@gmail.com': 1,
#  'xxxxawati07082006@gmail.com': 1,
#  'xxxxascita03@outlook.com': 1,
#  'xxxxarah28@gmail.com': 1,
#  'xxxxaamanda04@gmail.com': 1,
#  'xxxxi.syawalia.a@gmail.com': 1,
#  'xxxxelfirdaus94@gmail.com': 1,
#  'xxxxabi492005@gmail.com': 1,
#  'xxxxaaly08@gmail.com': 1,
#  'xxxxfa.putri766hi@gmail.com': 1,
#  'xxxxywiratami@gmail.com': 1,
#  'xxxxaarinanda237@gmail.com': 1,
#  'xxxxayofanda@gmail.com': 1,
#  'xxxxulansari842@gmail.com': 1,
#  'xxxxrsrafi3@gmail.com': 1,
#  'xxxxasalsabila977@gmail.com': 1,
#  'xxxxg765@gmail.com': 1,
#  'xxxxatraveltour@yahoo.com': 1,
#  'xxxxevina4904@gmail.com': 1,
#  'xxxxdxavierr@gmail.com': 1,
#  'xxxx04moenir@gmail.com': 1,
#  'xxxxnyaibrahim12@gmail.com': 1,
#  'xxxxsaaufa24@gmail.com': 1,
#  'xxxxibach144@gmail.com': 1,
#  'xxxxesiadiesta@gmail.com': 1,
#  'xxxxufaldi@gmail.com': 1,
#  'xxxxahmbc@gmail.com': 1,
#  'xxxxiyyu@gmail.com': 1,
#  'xxxxa.suherman@gmail.com': 1,
#  'xxxxdaniel338899@gmail.com': 1,
#  'xxxxatrianggraini7@gmail.com': 1,
#  'xxxxfaniesilalahi@gmail.com': 1,
#  'xxxxssawidiantoro12@gmail.com': 1,
#  'xxxxsetya248@gmail.com': 1,
#  'xxxxdhidayatmtsn5krw@gmail.com': 1,
#  'xxxxtaa04@gmail.com': 1,
#  'xxxxryshauqi@gmail.com': 1,
#  'xxxxvianinurhaliza@gmail.com': 1,
#  'xxxxhranisa994@gmail.com': 1,
#  'xxxxy.m4ulidan@gmail.com': 1,
#  'xxxxola_siregar@yahoo.com': 1,
#  'xxxxh140206@gmail.com': 1,
#  'xxxxmatikaariani15@gmail.com': 1,
#  'xxxxnezahranastiti@gmail.com': 1,
#  'xxxxrizki850@gmail.com': 1,
#  'xxxxsyajulianarambe@gmail.com': 1,
#  'xxxxhramadhanty2@gmail.com': 1,
#  'xxxxchairani@gmail.com': 1,
#  'xxxxoka.to28@gmail.com': 1,
#  'xxxxaannisa460@gmail.com': 1,
#  'xxxxamsul1@gmail.com': 1,
#  'xxxxnur104@gmail.com': 1,
#  'xxxxannapramesty@gmail.com': 1,
#  'xxxx.kireina@gmail.com': 1,
#  'xxxxammah.grace@gmail.com': 1,
#  'xxxxaayumumtaza@gmail.com': 1,
#  'xxxxarara28@gmail.com': 1,
#  'xxxxiahenanto253@gmail.com': 1,
#  'xxxxasiagian46@gmail.com': 1,
#  'xxxxael.naraya10@gmail.com': 1,
#  'xxxxianajia09@gmail.com': 1,
#  'xxxxputrih25@gmail.com': 1,
#  'xxxxitaharianja30@gmail.com': 1,
#  'xxxxa.fakhira05@gmail.com': 1,
#  'xxxxzalwicaksonobukhori@gmail.com': 1,
#  'xxxxasbahij04@gmail.com': 1,
#  'xxxxaviolettan@gmail.com': 1,
#  'xxxxafitriaudina02@gmail.com': 1,
#  'xxxxansyahagung239@gmail.com': 1,
#  'xxxxahkhairunnisa2006@gmail.com': 1,
#  'xxxxahmurtadlo05@gmail.com': 1,
#  'xxxxdrasalsabillaar3@gmail.com': 1,
#  'xxxxyp2512@gmail.com': 1,
#  'xxxxlicaaprilia3@gmail.com': 1,
#  'xxxxyadesti@gmail.com': 1,
#  'xxxxmmad.khoirulroziq@brainacademy.id': 1,
#  'xxxxrunnisa280506@gmail.com': 1,
#  'xxxxangestya@gmail.com': 1,
#  'xxxx1945comrade@gmail.com': 1,
#  'xxxxelim1710@gmail.com': 1,
#  'xxxxybkt@yahoo.co.id': 1,
#  'xxxxarahmasari980@gmail.com': 1,
#  'xxxxfa130806@gmail.com': 1,
#  'xxxxafriska@gmail.com': 1,
#  'xxxxgsadtria@gmail.com': 1,
#  'xxxxsahikaputriherra@gmail.com': 1,
#  'xxxxrmdnie12@gmail.com': 1,
#  'xxxxstinerotua05@gmail.com': 1,
#  'xxxxeensrijasmine@gmail.com': 1,
#  'xxxxliaaisyti64@gmail.com': 1,
#  'xxxxirakira436@gmail.com': 1,
#  'xxxxaagnesangel@gmail.com': 1,
#  'xxxxitaniswara06@gmail.com': 1,
#  'xxxxiasuciayu@gmail.com': 1,
#  'xxxxsrohidah1211@gmail.com': 1,
#  'xxxxzavanya@gmail.com': 1,
#  'xxxxistra12@gmail.com': 1,
#  'xxxxlsugianto4@gmail.com': 1,
#  'xxxxalutfiana@gmail.com': 1,
#  'xxxx_shohui@yahoo.com': 1,
#  'xxxxnarizka.rahmani@gmail.com': 1,
#  'xxxxramadhani05@gmail.com': 1,
#  'xxxxybadaruddin@gmail.com': 1,
#  'xxxxistareva@gmail.com': 1,
#  'xxxxpujirahayu085@gmail.com': 1,
#  'xxxxwahyu12333@gmail.com': 1,
#  'xxxxyayu2013@gmail.com': 1,
#  'xxxxku120779@gmail.com': 1,
#  'xxxxuberagung@gmail.com': 1,
#  'xxxxldwi11@gmail.com': 1,
#  'xxxxfadillah702@gmail.com': 1,
#  'xxxxiyaadhaaa@gmail.com': 1,
#  'xxxxaal81@gmail.com': 1,
#  'xxxxntroy2807@gmail.com': 1,
#  'xxxxinuraulia0506@gmail.com': 1,
#  'xxxxkojansouw27@gmail.com': 1,
#  'xxxxaangelia16@gmail.com': 1,
#  'xxxxatsaqifa4@gmail.com': 1,
#  'xxxxlyushfi@gmail.com': 1,
#  'xxxxiendahapsari@gmail.com': 1,
#  'xxxxgiantesalonika@gmail.com': 1,
#  'xxxxabdullahxxxx@gmail.com': 1,
#  'xxxxbaranazwa83@gmail.com': 1,
#  'xxxxasaputri089@gmail.com': 1,
#  'xxxxiliof@gmail.com': 1,
#  'xxxxgrace18@gmail.com': 1,
#  'xxxxsuprapti@gmail.com': 1,
#  'xxxxianidoloksaribu@gmail.com': 1,
#  'xxxxlaparamita2@gmail.com': 1,
#  'xxxxasuharsono@gmail.com': 1,
#  'xxxxditasalsa04@gmail.com': 1,
#  'xxxxn253@gmail.com': 1,
#  'xxxxngkasputra313@gmail.com': 1,
#  'xxxxok386@gmail.com': 1,
#  'xxxxmarsya0@gmail.com': 1,
#  'xxxxim0071@gmail.com': 1,
#  'xxxxilcoc@gmail.com': 1,
#  'xxxxyu.nayla@gmail.com': 1,
#  'xxxxynalpiinaa@gmail.com': 1,
#  'xxxxabila.syauqia@gmail.com': 1,
#  'xxxxaalya65@gmail.com': 1,
#  'xxxxsyaroni@gmail.com': 1,
#  'xxxxcsimon05@gmail.com': 1,
#  'xxxxahsiti16@yahoo.com': 1,
#  'xxxxuzgabriel@gmail.com': 1,
#  'xxxxanggraini.ren@gmail.com': 1,
#  'xxxxnaindra72@gmail.com': 1,
#  'xxxxfaunia@gmail.com': 1,
#  'xxxxtacheryl8@gmail.com': 1,
#  'xxxxmmadmaruf@sekolahathirah.sch.id': 1,
#  'xxxxyuhellen2@gmail.com': 1,
#  'xxxxwa901@gmail.com': 1,
#  'xxxxanbillah445@gmail.com': 1,
#  'xxxxysyukma@gmail.com': 1,
#  'xxxxccachandra2004@gmail.com': 1,
#  'xxxxeyraissa409@gmail.com': 1,
#  'xxxxdadewangga6@gmail.com': 1,
#  'xxxxsya27@gmail.com': 1,
#  'xxxxaghany@gmail.com': 1,
#  'xxxxjsca@gmail.com': 1,
#  'xxxxnz.ia20@gmail.com': 1,
#  'xxxxnaagustine2@gmail.com': 1,
#  'xxxxiciajeanneh24@gmail.com': 1,
#  'xxxxwulandari117@gmail.com': 1,
#  'xxxxartina123@gmail.com': 1,
#  'xxxxtia686@gmail.com': 1,
#  'xxxxunbraw@gmail.com': 1,
#  'xxxxdaputri93536@gmail.com': 1,
#  'xxxxnovi0303@gmail.com': 1,
#  'xxxxntinacahaya232@gmail.com': 1,
#  'xxxxijelli459@gmail.com': 1,
#  'xxxxasajja@gmail.com': 1,
#  'xxxxa10zulfa@gmail.com': 1,
#  'xxxxsitasulistriana@gmail.com': 1,
#  'xxxxfiazzahra02@gmail.com': 1,
#  'xxxxiarahma322@gmail.com': 1,
#  'xxxxtaesgurl@gmail.com': 1,
#  'xxxxiciakania2504@gmail.com': 1,
#  'xxxxmunul@gmail.com': 1,
#  'xxxxanga207@gmail.com': 1,
#  'xxxxunana@gmail.com': 1,
#  'xxxxlaganbintang100@gmail.com': 1,
#  'xxxxiatzzhr@gmail.com': 1,
#  'xxxxmingsekarcallistamukti11@gmail.com': 1,
#  'xxxxavita@gmail.com': 1,
#  'xxxxdahnaputri@gmail.com': 1,
#  'xxxxiana.nw06@gmail.com': 1,
#  'xxxxurrahmi10@gmail.com': 1,
#  'xxxxmadwafdan123@gmail.com': 1,
#  'xxxxahma.132000@gmail.com': 1,
#  'xxxxdwi924@gmail.com': 1,
#  'xxxxgalazka11@gmail.com': 1,
#  'xxxxsakusuma19@gmail.com': 1,
#  'xxxxtanrajif354@gmail.com': 1,
#  'xxxxsyaputri3@gmail.com': 1,
#  'xxxximanjuntak2016@gmail.com': 1,
#  'xxxxhfitriani37@gmail.com': 1,
#  'xxxxiracalista09@gmail.com': 1,
#  'xxxxlawijaya31@sma.belajar.id': 1,
#  'xxxxiatazkiyah266@gmail.com': 1,
#  'xxxxen.chenn21@gmail.com': 1,
#  'xxxxlia997@gmail.com': 1,
#  'xxxxaamelia220104@gmail.com': 1,
#  'xxxxdarahmanisa99@gmail.com': 1,
#  'xxxxabillahrahmadani19@gmail.com': 1,
#  'xxxxasirait26@gmail.com': 1,
#  'xxxxrtiaracitraaa@gmail.com': 1,
#  'xxxxiapauline5@gmail.com': 1,
#  'xxxxialamansyah729@gmail.com': 1,
#  'xxxxkawahyu96@gmail.com': 1,
#  'xxxxr18@gmail.com': 1,
#  'xxxxpujiastutik752@gmail.com': 1,
#  'xxxxalovita26@gmail.com': 1,
#  'xxxxadestya13@gmail.com': 1,
#  'xxxxamaangung@gmail.com': 1,
#  'xxxxatessaa@gmail.com': 1,
#  'xxxxansyar18@gmail.com': 1,
#  'xxxx39157@gmail.com': 1,
#  'xxxxkhesya26@gmail.com': 1,
#  'xxxx.triando@gmail.com': 1,
#  'xxxxranydewi5@gmail.com': 1,
#  'xxxxaanuris@gmail.com': 1,
#  'xxxx.tutuk@gmail.com': 1,
#  'xxxxdiazmi@gmail.com': 1,
#  'xxxxtaukaisilver@gmail.com': 1,
#  'xxxxaputri1711@gmail.com': 1,
#  'xxxxlcaesar12@gmail.com': 1,
#  'xxxxsaaulia373@gmail.com': 1,
#  'xxxximaula285@gmail.com': 1,
#  'xxxxsitio12@gmail.com': 1,
#  'xxxxar.sidik023@gmail.com': 1,
#  'xxxxadyaaulia04@gmail.com': 1,
#  'xxxxssanailla@gmail.com': 1,
#  'xxxxoronanda87@gmail.com': 1,
#  'xxxxclyst@gmail.com': 1,
#  'xxxxiaannisaa.13@gmail.com': 1,
#  'xxxxmarvin5@gmail.com': 1,
#  'xxxxsnaufal@gmail.com': 1,
#  'xxxxda.sekar.cendikia@gmail.com': 1,
#  'xxxxdarizka1166@gmail.com': 1,
#  'xxxxkhiasfana@gmail.com': 1,
#  'xxxxriyahyanayla@gmail.com': 1,
#  'xxxxstianhose20@gmail.com': 1,
#  'xxxxie.iphone2004@gmail.com': 1,
#  'xxxxtatambunan6@gmail.com': 1,
#  'xxxxaraanindhyta@gmail.com': 1,
#  'xxxxndixxxxndi@gmail.com': 1,
#  'xxxxa3589@gmail.com': 1,
#  'xxxxodrachmaningrum@gmail.com': 1,
#  'xxxxaelleoforensiusharianja@gmail.com': 1,
#  'xxxxnoahgalkasaputra@gmail.com': 1,
#  'xxxxndriyani333@gmail.com': 1,
#  'xxxxreitavarianti@gmail.com': 1,
#  'xxxxa010406@gmail.com': 1,
#  'xxxx1572@gmail.com': 1,
#  'xxxxlyn.tar3@gmail.com': 1,
#  'xxxxmy0604@gmail.com': 1,
#  'xxxxsitorus67@gmail.com': 1,
#  'xxxxshifa@gmail.com': 1,
#  'xxxxaindriyani97@gmail.com': 1,
#  'xxxxghifari@gmail.com': 1,
#  'xxxxestianib@gmail.com': 1,
#  'xxxxnpradnya546@gmail.com': 1,
#  'xxxxatsitorus5@gmail.com': 1,
#  'xxxxazulfa01@gmail.com': 1,
#  'xxxxinihayanuhairo@gmail.com': 1,
#  'xxxxunapaembonan@gmail.com': 1,
#  'xxxxyafadhilah@gmail.com': 1,
#  'xxxxasugiono69@gmail.com': 1,
#  'xxxxnacelia20@gmail.com': 1,
#  'xxxxiaryakrisna@gmail.com': 1,
#  'xxxxaki.nugroho@gmail.com': 1,
#  'xxxxmmadjidan634@gmail.com': 1,
#  'xxxxtya399@gmail.com': 1,
#  'xxxxeraherdani18@gmail.com': 1,
#  'xxxxnenadya.xmipa7@gmail.com': 1,
#  'xxxxlazulfa814@gmail.com': 1,
#  'xxxxanurathallah@gmail.com': 1,
#  'xxxxakeanu.ratu@gmail.com': 1,
#  'xxxxalreza962a@gmail.com': 1,
#  'xxxxllindra.10@gmail.com': 1,
#  'xxxxza161004@gmail.com': 1,
#  'xxxxafaza@gmail.com': 1,
#  'xxxxiesa34@gmail.com': 1,
#  'xxxxnmartha0906@gmail.com': 1,
#  'xxxxeptiani@gmail.com': 1,
#  'xxxxaaqila2019@gmail.com': 1,
#  'xxxx22yk.131@gmail.com': 1,
#  'xxxxiyah384@gmail.com': 1,
#  'xxxxatanirfaulya@gmail.com': 1,
#  'xxxxzsuryajagad05@gmail.com': 1,
#  'xxxxalfiani81@smp.belajar.id': 1,
#  'xxxxianesha874@gmail.com': 1,
#  'xxxxhyaavrilianda@gmail.com': 1,
#  'xxxxielginting@gmail.com': 1,
#  'xxxxyvivian781@gmail.com': 1,
#  'xxxxanfauzy15@gmail.com': 1,
#  'xxxxalfebri@gmail.com': 1,
#  'xxxxasekar1123@gmail.com': 1,
#  'xxxxprlhyejin@gmail.com': 1,
#  'xxxxda17fakhira@gmail.com': 1,
#  'xxxxaafnani@gmail.com': 1,
#  'xxxxliana05@gmail.com': 1,
#  'xxxxnovenajasmine@gmail.com': 1,
#  'xxxxyuaulia013@gmail.com': 1,
#  'xxxxirak44@gmail.com': 1,
#  'xxxxzs0747@gmail.com': 1,
#  'xxxxardayarum@gmail.com': 1,
#  'xxxxinaalinda09@gmail.com': 1,
#  'xxxxnnailahramadhani@gmail.com': 1,
#  'xxxxanazarinaa@gmail.com': 1,
#  'xxxxyaputrichania@gmail.com': 1}

# %% [markdown]
# FUN FACT!!
#
# Index(['Question ID', 'Question Created At', 'Subject', 'Class', 'Email',
#        'PackageType', 'Created vs answered hour diff'],
#       dtype='object')

# %%
# Murid yang aktif di tiap Subject
stud_sub = {}
for s in data['Subject'].unique():
    spec_sub = data[data['Subject'] == s]
    stud_sub[s] = spec_sub['Email'].mode()[0]
stud_sub
# Out:
# {'Matematika': 'xxxxaulida@gmail.com',
#  'Kimia': 'xxxxlcaesar12@gmail.com',
#  'Bahasa Inggris': 'xxxxntinacahaya232@gmail.com',
#  'Biologi': 'xxxxahengie@gmail.com',
#  'Bahasa Indonesia': 'xxxxaschy@gmail.com',
#  'Ekonomi': 'xxxx0509@gmail.com',
#  'IPS Terpadu': 'xxxxaassyifa@gmail.com',
#  'Fisika': 'xxxxiatazkiyah266@gmail.com',
#  'Sejarah': 'xxxxraputri.7d@gmail.com',
#  'IPA Terpadu': 'xxxxanamom@gmail.com',
#  'Geografi': 'xxxxa5723@gmail.com',
#  'Sosiologi': 'xxxxadestya13@gmail.com'}

# %%
# Data jumlah penanya dari tiap jenjang
class_stud = {}
for c in data['Class'].unique():
    class_list = data[data['Class'] == c]
    class_stud[c] = len(class_list)
class_stud = dict(sorted(class_stud.items(),
                         key=lambda item: item[1],
                         reverse=True))
class_stud
# Out:
# {'IPA': 945,
#  '11 SMA IPA': 613,
#  '10 SMA IPA': 524,
#  '9 SMP': 467,
#  '8 SMP': 178,
#  'IPS': 131,
#  '7 SMP': 81,
#  '11 SMA IPS': 80,
#  '4 SD': 78,
#  '6 SD': 66,
#  '5 SD': 53,
#  '10 SMA IPS': 47,
#  '12 SMA IPS': 7,
#  '3 SD': 1,
#  '12 SMA IPA': 1,
#  nan: 0}

# %%
# Penanya terbanyak
data['Email'].mode()
# Out:
# 0    xxxxntinacahaya232@gmail.com
# dtype: object

# %%
# Package paling aktif dan yang kureng
pack_act = {}
for p in data['PackageType'].unique():
    spec_pack = data[data['PackageType'] == p]
    pack_act[p] = len(spec_pack)
pack_act = dict(sorted(pack_act.items(),
                       key=lambda item: item[1],
                       reverse=True))
pack_act
# Out:
# {'REGULAR': 1864, 'PREMIUM': 1383, 'ELITE': 38}
